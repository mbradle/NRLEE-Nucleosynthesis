# %% [markdown]
# # Print out data.

# %% [markdown]
# Begin by installing necessary packages.

# %%
import sys
# !{sys.executable} -m pip install --quiet requests xmlcoll pandas

# %% [markdown]
# Next, import the necessary packages:

# %%
import os, io, requests
import xmlcoll as xc

# %% [markdown]
# First retrieve the meteoritic data.

# %%
my_collection = xc.coll.Collection()
my_collection.update_from_xml(io.BytesIO(requests.get('https://osf.io/wj5rd/download').content))
#my_collection.update_from_xml('leya_et_al_2009_Ti.xml')

# %% [markdown]
# Print out global properties.

# %%
global_props = my_collection.get_properties()
species = []
for key, value in global_props.items():
    print(key, ':', value)

# %% [markdown]
# Print out all samples and their properties.

# %%
for item in my_collection.get().values():
    print(f"Sample: {item.get_name()}\n")
    for k, v in item.get_properties().items():
        print(k, ':', v)
    print("\n\n")
# Out:
# Sample: Bulk Earth
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 0.7
# ('mu', 'cr54', 'value') : 8.9
# ('mu', 'ca48', 'variability of sample') : 2.8
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 1.1
# ('mu', 'ti46', 'variability of sample') : 1.2
# ('mu', 'ni58', 'value') : 8.4
# ('mu', 'ni58', 'number of data points') : 6.0
# ('mu', 'ca48', 'value') : 1.4
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 19.0
# ('mu', 'Ti46', 'value') : -0.3
# ('mu', 'ca48', 'number of data points') : 11.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'value') : -0.3
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 34.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 29.0
# ('mu', 'fe54', 'variability of sample') : 2.0
# ('mu', 'cr54', 'variability of sample') : 2.2
# ('mu', 'Ti46', 'number of data points') : 32.0
# ('mu', 'ni58', 'variability of sample') : 6.2
#
#
#
# Sample: HED 4-Vesta
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 11.7
# ('mu', 'cr54', 'value') : -69.7
# ('mu', 'ca48', 'variability of sample') : 17.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 2.4
# ('mu', 'ti46', 'variability of sample') : 2.9
# ('mu', 'ca48', 'value') : -121.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 5.0
# ('mu', 'Ti46', 'value') : -24.8
# ('mu', 'ca48', 'number of data points') : 23.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : -124.0
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 19.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 17.0
# ('mu', 'fe54', 'variability of sample') : 2.4
# ('mu', 'cr54', 'variability of sample') : 3.2
# ('mu', 'Ti46', 'number of data points') : 17.0
#
#
#
# Sample: Ordinary chondrite
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 10.5
# ('mu', 'cr54', 'value') : -40.1
# ('mu', 'ca48', 'variability of sample') : 6.3
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 2.2
# ('mu', 'ti46', 'variability of sample') : 2.3
# ('mu', 'ni58', 'value') : -19.7
# ('mu', 'ni58', 'number of data points') : 13.0
# ('mu', 'ca48', 'value') : -33.5
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'number of data points') : 9.0
# ('mu', 'Ti46', 'value') : -8.5
# ('mu', 'ca48', 'number of data points') : 11.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : -62.9
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 13.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 12.0
# ('mu', 'fe54', 'variability of sample') : 2.6
# ('mu', 'cr54', 'variability of sample') : 2.5
# ('mu', 'Ti46', 'number of data points') : 9.0
# ('mu', 'ni58', 'variability of sample') : 4.1
#
#
#
# Sample: Angrite
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'cr54', 'value') : -44.0
# ('mu', 'ca48', 'variability of sample') : 17.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 2.0
# ('mu', 'ti46', 'variability of sample') : 1.9
# ('mu', 'ca48', 'value') : -117.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'Ti46', 'value') : -20.3
# ('mu', 'ca48', 'number of data points') : 11.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'value') : -113.6
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 14.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 3.0
# ('mu', 'cr54', 'variability of sample') : 12.0
# ('mu', 'Ti46', 'number of data points') : 8.0
#
#
#
# Sample: Enstatite
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 6.4
# ('mu', 'cr54', 'value') : 16.0
# ('mu', 'ca48', 'variability of sample') : 23.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 6.4
# ('mu', 'ti46', 'variability of sample') : 2.2
# ('mu', 'ni58', 'value') : 0.0
# ('mu', 'ni58', 'number of data points') : 5.0
# ('mu', 'ca48', 'value') : -37.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'number of data points') : 4.0
# ('mu', 'Ti46', 'value') : 0.5
# ('mu', 'ca48', 'number of data points') : 3.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : -16.3
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 8.0
# ('mu', 'ca48', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'number of data points') : 13.0
# ('mu', 'fe54', 'variability of sample') : 0.7
# ('mu', 'cr54', 'variability of sample') : 4.1
# ('mu', 'Ti46', 'number of data points') : 8.0
# ('mu', 'ni58', 'variability of sample') : 14.0
#
#
#
# Sample: Mesosiderite
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'cr54', 'value') : -72.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 9.5
# ('mu', 'ti46', 'variability of sample') : 1.4
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'Ti46', 'value') : 2.1
# type : NC
# ('mu', 'ti50', 'value') : -126.0
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05 (even though probability if 0.04 - huge error for constant external error calculation
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 3.0
# ('mu', 'cr54', 'number of data points') : 4.0
# ('mu', 'cr54', 'variability of sample') : 2.7
# ('mu', 'Ti46', 'number of data points') : 2.0
#
#
#
# Sample: Pallasite (Krasnojarsk; Admire olivine for Ti data)
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'value') : -73.0
# ('mu', 'ti50', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'variability of sample') : 8.0
# ('mu', 'ti46', 'variability of sample') : 9.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'Ti46', 'value') : -12.0
# type : NC
# ('mu', 'ti50', 'value') : -137.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 1.0
# ('mu', 'cr54', 'number of data points') : 2.0
# ('mu', 'cr54', 'variability of sample') : 1.9
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: Eagle Station Pallasite
#
# ('mu', 'cr54', 'value') : 71.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# type : NC
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'cr54', 'number of data points') : 2.0
# ('mu', 'cr54', 'variability of sample') : 18.0
#
#
#
# Sample: Lunar
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'cr54', 'value') : 9.0
# ('mu', 'ca48', 'variability of sample') : 3.3
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 3.0
# ('mu', 'ti46', 'variability of sample') : 1.4
# ('mu', 'ca48', 'value') : 4.6
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# ('mu', 'Ti46', 'value') : 2.1
# ('mu', 'ca48', 'number of data points') : 4.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'value') : -9.1
# ('mu', 'Ti46', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'number of data points') : 25.0
# ('mu', 'ca48', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'number of data points') : 21.0
# ('mu', 'cr54', 'variability of sample') : 8.0
# ('mu', 'Ti46', 'number of data points') : 25.0
#
#
#
# Sample: Mars
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 6.5
# ('mu', 'cr54', 'value') : -18.1
# ('mu', 'ca48', 'variability of sample') : 9.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 18.0
# ('mu', 'ti46', 'variability of sample') : 4.0
# ('mu', 'ca48', 'value') : -9.5
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'number of data points') : 4.0
# ('mu', 'Ti46', 'value') : -41.0
# ('mu', 'ca48', 'number of data points') : 18.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : -41.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 8.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 10.0
# ('mu', 'fe54', 'variability of sample') : 1.5
# ('mu', 'cr54', 'variability of sample') : 1.9
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: Aubrite
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'ca48', 'variability of sample') : 59.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 7.5
# ('mu', 'ti46', 'variability of sample') : 3.0
# ('mu', 'ca48', 'value') : -44.0
# ('mu', 'Ti46', 'value') : 1.0
# ('mu', 'ca48', 'number of data points') : 1.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'value') : -6.5
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'number of data points') : 4.0
# ('mu', 'ca48', 'Statistics decision') : as reported in paper
# ('mu', 'Ti46', 'number of data points') : 4.0
#
#
#
# Sample: Winonanite
#
# ('mu', 'ca48', 'variability of sample') : 8.6
# ('mu', 'ca48', 'value') : -21.3
# ('mu', 'ca48', 'number of data points') : 1.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : as reported in paper
# ('mu', 'ca48', 'Statistics decision') : as reported in paper
#
#
#
# Sample: Ureilite
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 13.9
# ('mu', 'cr54', 'value') : -60.0
# ('mu', 'ca48', 'variability of sample') : 21.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 28.0
# ('mu', 'ti46', 'variability of sample') : 12.0
# ('mu', 'ca48', 'value') : -194.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 8.0
# ('mu', 'Ti46', 'value') : -21.0
# ('mu', 'ca48', 'number of data points') : 19.0
# type : NC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : -197.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 4.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 13.0
# ('mu', 'fe54', 'variability of sample') : 2.8
# ('mu', 'cr54', 'variability of sample') : 22.0
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: IAB
#
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 2.9
# ('mu', 'fe54', 'number of data points') : 11.0
# type : NC
# ('mu', 'fe54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'variability of sample') : 4.7
#
#
#
# Sample: IIAB
#
# ('mu', 'fe54', 'Type of error ') : as reported in paper (pre-GCR exposure average)
# ('mu', 'fe54', 'value') : 16.0
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : -25.6
# ('mu', 'ni58', 'number of data points') : 2.0
# ('mu', 'fe54', 'number of data points') : 3.0
# type : NC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : 1 value reported
# ('mu', 'fe54', 'variability of sample') : 4.0
# ('mu', 'ni58', 'variability of sample') : 9.8
#
#
#
# Sample: IIIAB
#
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 13.0
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : -29.0
# ('mu', 'ni58', 'number of data points') : 3.0
# ('mu', 'fe54', 'number of data points') : 10.0
# type : NC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'variability of sample') : 3.2
# ('mu', 'ni58', 'variability of sample') : 18.0
#
#
#
# Sample: IVA
#
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 19.0
# ('mu', 'ni58', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'value') : -20.0
# ('mu', 'ni58', 'number of data points') : 5.0
# ('mu', 'fe54', 'number of data points') : 3.0
# type : NC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'variability of sample') : 21.0
# ('mu', 'ni58', 'variability of sample') : 12.0
#
#
#
# Sample: IC
#
# ('mu', 'fe54', 'Type of error ') : as reported in paper (pre-GCR exposure average)
# ('mu', 'fe54', 'value') : 10.0
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : -15.0
# ('mu', 'ni58', 'number of data points') : 5.0
# ('mu', 'fe54', 'number of data points') : 1.0
# type : NC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : 1 value reported
# ('mu', 'fe54', 'variability of sample') : 8.0
# ('mu', 'ni58', 'variability of sample') : 13.0
#
#
#
# Sample: IIIE
#
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : -22.0
# ('mu', 'ni58', 'number of data points') : 5.0
# type : NC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'ni58', 'variability of sample') : 11.0
#
#
#
# Sample: Rumuruti (R)
#
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 6.4
# ('mu', 'cr54', 'value') : -11.0
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# ('mu', 'fe54', 'number of data points') : 1.0
# type : NC
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'number of data points') : 1.0
# ('mu', 'fe54', 'variability of sample') : 0.8
# ('mu', 'cr54', 'variability of sample') : 25.0
#
#
#
# Sample: Acapulcoite
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'value') : -60.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 18.0
# ('mu', 'ti46', 'variability of sample') : 5.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'Ti46', 'value') : -14.0
# type : NC
# ('mu', 'ti50', 'value') : -132.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 3.0
# ('mu', 'cr54', 'number of data points') : 3.0
# ('mu', 'cr54', 'variability of sample') : 15.0
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: Brachinite
#
# ('mu', 'cr54', 'value') : -46.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 26.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# type : NC
# ('mu', 'ti50', 'value') : -138.0
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 4.0
# ('mu', 'cr54', 'number of data points') : 4.0
# ('mu', 'cr54', 'variability of sample') : 11.0
#
#
#
# Sample: Lodranite
#
# ('mu', 'cr54', 'value') : -59.0
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 24.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# type : NC
# ('mu', 'ti50', 'value') : -163.0
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 2.0
# ('mu', 'cr54', 'number of data points') : 2.0
# ('mu', 'cr54', 'variability of sample') : 9.0
#
#
#
# Sample: CI
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : -2.0
# ('mu', 'cr54', 'value') : 156.9
# ('mu', 'ca48', 'variability of sample') : 7.7
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 8.2
# ('mu', 'ti46', 'variability of sample') : 3.4
# ('mu', 'ni58', 'value') : 43.0
# ('mu', 'ni58', 'number of data points') : 1.0
# ('mu', 'ca48', 'value') : 206.1
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'number of data points') : 9.0
# ('mu', 'Ti46', 'value') : 35.7
# ('mu', 'ca48', 'number of data points') : 3.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : 183.0
# ('mu', 'Ti46', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 5.0
# ('mu', 'ca48', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'cr54', 'number of data points') : 10.0
# ('mu', 'fe54', 'variability of sample') : 2.7
# ('mu', 'cr54', 'variability of sample') : 3.7
# ('mu', 'Ti46', 'number of data points') : 2.0
# ('mu', 'ni58', 'variability of sample') : 19.0
#
#
#
# Sample: CO
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 12.8
# ('mu', 'cr54', 'value') : 70.0
# ('mu', 'ca48', 'variability of sample') : 56.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 63.0
# ('mu', 'ti46', 'variability of sample') : 14.0
# ('mu', 'ni58', 'value') : 39.0
# ('mu', 'ni58', 'number of data points') : 1.0
# ('mu', 'ca48', 'value') : 387.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 2.0
# ('mu', 'Ti46', 'value') : 59.0
# ('mu', 'ca48', 'number of data points') : 1.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : as reported in paper
# ('mu', 'ni58', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'value') : 340.0
# ('mu', 'Ti46', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 6.0
# ('mu', 'ca48', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'number of data points') : 5.0
# ('mu', 'fe54', 'variability of sample') : 7.6
# ('mu', 'cr54', 'variability of sample') : 13.0
# ('mu', 'Ti46', 'number of data points') : 4.0
# ('mu', 'ni58', 'variability of sample') : 14.0
#
#
#
# Sample: CM
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'cr54', 'value') : 98.2
# ('mu', 'ca48', 'variability of sample') : 85.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 12.0
# ('mu', 'ti46', 'variability of sample') : 2.6
# ('mu', 'ni58', 'value') : 33.0
# ('mu', 'ni58', 'number of data points') : 2.0
# ('mu', 'ca48', 'value') : 297.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'Ti46', 'value') : 57.2
# ('mu', 'ca48', 'number of data points') : 2.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'ti50', 'value') : 300.0
# ('mu', 'Ti46', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 14.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 11.0
# ('mu', 'cr54', 'variability of sample') : 4.8
# ('mu', 'Ti46', 'number of data points') : 9.0
# ('mu', 'ni58', 'variability of sample') : 18.0
#
#
#
# Sample: CV3
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 22.1
# ('mu', 'cr54', 'value') : 87.3
# ('mu', 'ca48', 'variability of sample') : 68.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 6.5
# ('mu', 'ti46', 'variability of sample') : 4.4
# ('mu', 'ni58', 'value') : 39.0
# ('mu', 'ni58', 'number of data points') : 4.0
# ('mu', 'ca48', 'value') : 356.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 1.0
# ('mu', 'Ti46', 'value') : 60.7
# ('mu', 'ca48', 'number of data points') : 3.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : 331.7
# ('mu', 'Ti46', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 22.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 16.0
# ('mu', 'fe54', 'variability of sample') : 3.6
# ('mu', 'cr54', 'variability of sample') : 4.7
# ('mu', 'Ti46', 'number of data points') : 21.0
# ('mu', 'ni58', 'variability of sample') : 11.0
#
#
#
# Sample: CR
#
# ('mu', 'Ti46', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 28.8
# ('mu', 'cr54', 'value') : 133.0
# ('mu', 'ca48', 'variability of sample') : 24.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 44.0
# ('mu', 'ti46', 'variability of sample') : 51.0
# ('mu', 'ni58', 'value') : 22.0
# ('mu', 'ni58', 'number of data points') : 1.0
# ('mu', 'ca48', 'value') : 215.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 3.0
# ('mu', 'Ti46', 'value') : 48.0
# ('mu', 'ca48', 'number of data points') : 2.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : 95% conf
# ('mu', 'ni58', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : 246.0
# ('mu', 'Ti46', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 7.0
# ('mu', 'ca48', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'cr54', 'number of data points') : 7.0
# ('mu', 'fe54', 'variability of sample') : 4.4
# ('mu', 'cr54', 'variability of sample') : 9.2
# ('mu', 'Ti46', 'number of data points') : 2.0
# ('mu', 'ni58', 'variability of sample') : 21.0
#
#
#
# Sample: CH
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 15.5
# ('mu', 'ti50', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'variability of sample') : 44.0
# ('mu', 'ti46', 'variability of sample') : 10.0
# ('mu', 'fe54', 'number of data points') : 1.0
# ('mu', 'Ti46', 'value') : 50.0
# type : CC
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : 246.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'number of data points') : 1.0
# ('mu', 'fe54', 'variability of sample') : 6.6
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: C2-ung (tagish Lake)
#
# ('mu', 'cr54', 'value') : 134.0
# ('mu', 'ca48', 'variability of sample') : 5.3
# ('mu', 'ca48', 'value') : 291.3
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ca48', 'number of data points') : 1.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ca48', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'number of data points') : 2.0
# ('mu', 'cr54', 'variability of sample') : 39.0
#
#
#
# Sample: Niger I (C2)
#
# ('mu', 'cr54', 'value') : 158.5
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# type : CC
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'number of data points') : 1.0
# ('mu', 'cr54', 'variability of sample') : 11.2
#
#
#
# Sample: NWA 5958 (C3.0)
#
# ('mu', 'cr54', 'value') : 101.2
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# type : CC
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'number of data points') : 1.0
# ('mu', 'cr54', 'variability of sample') : 13.1
#
#
#
# Sample: IVB
#
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 27.3
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : 29.7
# ('mu', 'ni58', 'number of data points') : 5.0
# ('mu', 'fe54', 'number of data points') : 6.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'fe54', 'variability of sample') : 29.0
# ('mu', 'ni58', 'variability of sample') : 3.4
#
#
#
# Sample: IID
#
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : 54.0
# ('mu', 'ni58', 'number of data points') : 3.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'ni58', 'variability of sample') : 20.0
#
#
#
# Sample: IIF
#
# ('mu', 'ni58', 'Statistics decision') : as reported in paper
# ('mu', 'ni58', 'value') : 28.0
# ('mu', 'ni58', 'number of data points') : 1.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : as reported in paper
# ('mu', 'ni58', 'variability of sample') : 11.0
#
#
#
# Sample: IIIF
#
# ('mu', 'ni58', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'value') : 37.0
# ('mu', 'ni58', 'number of data points') : 3.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'ni58', 'variability of sample') : 29.0
#
#
#
# Sample: IIC
#
# ('mu', 'fe54', 'Type of error ') : 95% conf
# ('mu', 'fe54', 'value') : 35.0
# ('mu', 'ni58', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ni58', 'value') : 48.0
# ('mu', 'ni58', 'number of data points') : 5.0
# ('mu', 'fe54', 'number of data points') : 5.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : 95% conf.
# ('mu', 'fe54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'variability of sample') : 4.2
# ('mu', 'ni58', 'variability of sample') : 13.0
#
#
#
# Sample: CK
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'Type of error ') : as reported in paper
# ('mu', 'fe54', 'value') : 26.0
# ('mu', 'cr54', 'value') : 49.0
# ('mu', 'ti50', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 110.0
# ('mu', 'ti46', 'variability of sample') : 8.0
# ('mu', 'cr54', 'Statistics decision') : a weighted mean combining the assigned error and a constant external error when the probability of fit is below 0.05
# ('mu', 'fe54', 'number of data points') : 2.0
# ('mu', 'Ti46', 'value') : 61.0
# type : CC
# ('mu', 'fe54', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'value') : 362.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 2.0
# ('mu', 'cr54', 'number of data points') : 2.0
# ('mu', 'fe54', 'variability of sample') : 6.1
# ('mu', 'cr54', 'variability of sample') : 46.0
# ('mu', 'Ti46', 'number of data points') : 1.0
#
#
#
# Sample: Cba (Gjuba/Bencubbin CB)
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'value') : 111.7
# ('mu', 'ti50', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'ni58', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'variability of sample') : 6.8
# ('mu', 'ti46', 'variability of sample') : 10.0
# ('mu', 'ni58', 'value') : 49.0
# ('mu', 'ni58', 'number of data points') : 1.0
# ('mu', 'cr54', 'Statistics decision') : a straight weighted mean when the probability of fit is above 0.05
# ('mu', 'Ti46', 'value') : 39.0
# type : CC
# ('mu', 'ni58', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'value') : 203.5
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : 95% conf
# ('mu', 'ti50', 'number of data points') : 2.0
# ('mu', 'cr54', 'number of data points') : 3.0
# ('mu', 'cr54', 'variability of sample') : 6.1
# ('mu', 'Ti46', 'number of data points') : 1.0
# ('mu', 'ni58', 'variability of sample') : 30.0
#
#
#
# Sample: Almahatta Sitta
#
# type : CC
#
#
#
# Sample: Tafassasset
#
# ('mu', 'cr54', 'value') : 144.0
# ('mu', 'ti50', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'variability of sample') : 106.0
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# type : CC
# ('mu', 'ti50', 'value') : 208.0
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'number of data points') : 1.0
# ('mu', 'cr54', 'number of data points') : 1.0
# ('mu', 'cr54', 'variability of sample') : 8.0
#
#
#
# Sample: Ung Achondrite NWA 2976 - odd sample not plotting where other CCs plot!
#
# ('mu', 'Ti46', 'Type of error ') : as reported in paper
# ('mu', 'cr54', 'value') : -61.0
# ('mu', 'ca48', 'variability of sample') : 10.0
# ('mu', 'ti50', 'Statistics decision') : as reported in paper
# ('mu', 'ti50', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'variability of sample') : 11.0
# ('mu', 'ti46', 'variability of sample') : 7.0
# ('mu', 'ca48', 'value') : 284.9
# ('mu', 'cr54', 'Statistics decision') : as reported in paper
# ('mu', 'Ti46', 'value') : 54.0
# ('mu', 'ca48', 'number of data points') : 1.0
# type : CC
# ('mu', 'ca48', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'value') : 309.0
# ('mu', 'Ti46', 'Statistics decision') : as reported in paper
# ('mu', 'cr54', 'Type of error ') : as reported in paper
# ('mu', 'ti50', 'number of data points') : 1.0
# ('mu', 'ca48', 'Statistics decision') : 1 value reported
# ('mu', 'cr54', 'number of data points') : 1.0
# ('mu', 'cr54', 'variability of sample') : 11.0
# ('mu', 'Ti46', 'number of data points') : 1.0
